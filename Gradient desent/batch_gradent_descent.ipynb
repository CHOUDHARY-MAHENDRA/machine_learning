# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

from sklearn.datasets import make_regression

# %%
# %matplotlib.pyplot

# %%
from matplotlib.animation import FuncAnimation
import matplotlib.animation as anima

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative =1, n_targets=1,noise=20,random_state=13)

# %%
x.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(x,y)
plt.show()

# %%
b=-520
m=600
lr=0.001
all_b=[]
all_m=[]
# all_cos=[]

epochs=30

for i in range(epochs):
    slope_b=0
    slope_m=0
    cost=0
    
    plt.scatter(x,y,color='blue')

    for j in range(x.shape[0]):
        slope_b=slope_b-2*(y[j]-(m*x[j])-b)
        slope_m=slope_m-2*x[j]*(y[j]-(m*x[j])-b)
        # cost=cost-(y[j]-(m*x[j])-b)**2
    b=b-(lr*slope_b)
    m=m-(lr*slope_m)

    plt.subplots(figsize=(9,5))

    x_i=np.arange(-3,3,0.1)
    y_i=np.array(x_i*(m)-b)
    plt.scatter(x_i,y_i, color='red')

    all_b.append(b)
    all_m.append(m)
    # all_cos.append(cost)
# Out:
# C:\Users\choud\AppData\Local\Temp\ipykernel_17824\849048132.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.subplots(figsize=(9,5))

# %%
# all_cos
# all_b
b , m
# Out:
# (array([-3.54124887]), array([30.24770388]))

# %%
plt.subplots(figsize=(9,5))

x_i=np.arange(-3,3,0.1)
y_i=np.array(x_i*(m)-b)

plt.scatter(x,y,color='blue')
plt.scatter(x_i,y_i, color='red')
